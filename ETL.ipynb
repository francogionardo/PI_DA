# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data_set/indicadores_macro.csv', sep =',')
df = df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#      Año  Trimestre  IPC US  IPC AR USDARS oficial USDARS blue PBI millones
# 0   2013          1  232773     298           5,00        9,00    2.888.981
# 1   2013          2  233504     309           5,00        9,00    3.387.811
# 2   2013          3  234149     331           6,00       10,00    3.436.547
# 3   2013          4  233049     351           6,00       11,00    3.679.896
# 4   2014          1  236293     402           8,00       11,00    3.917.649
# 5   2014          2  238343     433           8,00       13,00    4.702.630
# 6   2014          3  238031     461           8,00       14,00    4.685.503
# 7   2014          4  234812     491           9,00       13,00    5.010.564
# 8   2015          1  236119     518           9,00       13,00    5.092.694
# 9   2015          2  238638     549           9,00       15,00    5.951.479
# 10  2015          3  237945     584           9,00       15,00    6.221.731
# ...

# %%
df1= pd.read_csv('data_set/ingreso_internet_fijo_trimestral.csv', sep=',')
df1 = df1.drop(columns=['Unnamed: 0'])

# %%
df_merged = pd.merge(df, df1, on=['Año', 'Trimestre'], how='outer')

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Año                        39 non-null     int64
#  1   Trimestre                  39 non-null     int64
#  2   IPC US                     22 non-null     float64
#  3   IPC AR                     22 non-null     float64
#  4   USDARS oficial             22 non-null     object
#  5   USDARS blue                22 non-null     object
#  6   PBI millones               21 non-null     object
#  7   Ingresos (miles de pesos)  35 non-null     object
#  8   Periodo                    35 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 2.9+ KB

# %%
df2= pd.read_csv('data_set/internet_bancha_bangosta.csv', sep=',')
df2 = df2.drop(columns=['Unnamed: 0'])
df2 = df2.drop(columns=['Periodo'])

# %%
df2
# Out:
#      Año  Trimestre Banda ancha fija  Dial up       Total        Periodo
# 0   2022          3       11.078.691   12.437  11.091.128  Jul-Sept 2022
# 1   2022          2       10.946.248   12.436  10.958.684   Abr-Jun 2022
# 2   2022          1       10.611.390   12.619  10.624.009   Ene-Mar 2022
# 3   2021          4       10.476.933   12.861  10.489.794   Oct-Dic 2021
# 4   2021          3       10.075.184   10.357  10.085.541  Jul-Sept 2021
# 5   2021          2        9.852.702   10.382   9.863.084   Abr-Jun 2021
# 6   2021          1        9.637.956   10.016   9.647.972   Ene-Mar 2021
# 7   2020          4        9.561.546   10.016   9.571.562   Oct-Dic 2020
# 8   2020          3        9.346.183   10.016   9.356.199  Jul-Sept 2020
# 9   2020          2        9.021.040   10.016   9.031.056   Abr-Jun 2020
# 10  2020          1        8.802.435    9.991   8.812.426   Ene-Mar 2020
# 11  2019          4        8.783.053   10.128   8.793.181   Oct-Dic 2019
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Año               39 non-null     int64
#  1   Trimestre         39 non-null     int64
#  2   Banda ancha fija  35 non-null     object
#  3   Dial up           35 non-null     float64
#  4   Total             35 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.7+ KB

# %%
df_merged = pd.merge(df_merged, df2, on=['Año', 'Trimestre'], how='outer')
df_merged = df_merged[df_merged.columns.intersection(df2.columns)]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Año               39 non-null     int64
#  1   Trimestre         39 non-null     int64
#  2   Banda ancha fija  35 non-null     object
#  3   Dial up           35 non-null     float64
#  4   Total             35 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.7+ KB

# %%
df_merged
# Out:
#      Año  Trimestre    IPC US  IPC AR USDARS oficial USDARS blue PBI millones  \
# 0   2013          1  232773.0   298.0           5,00        9,00    2.888.981
# 1   2013          2  233504.0   309.0           5,00        9,00    3.387.811
# 2   2013          3  234149.0   331.0           6,00       10,00    3.436.547
# 3   2013          4  233049.0   351.0           6,00       11,00    3.679.896
# 4   2014          1  236293.0   402.0           8,00       11,00    3.917.649
# 5   2014          2  238343.0   433.0           8,00       13,00    4.702.630
# 6   2014          3  238031.0   461.0           8,00       14,00    4.685.503
# 7   2014          4  234812.0   491.0           9,00       13,00    5.010.564
# 8   2015          1  236119.0   518.0           9,00       13,00    5.092.694
# 9   2015          2  238638.0   549.0           9,00       15,00    5.951.479
# 10  2015          3  237945.0   584.0           9,00       15,00    6.221.731
# ...

# %%
df3 = pd.read_csv('data_set/internet_bancha_bangosta_prov.csv', sep=',')

# %%
df3
# Out:
#      Unnamed: 0   Año  Trimestre            Provincia Banda ancha fija  \
# 0             0  2022          3         Buenos Aires        4.715.469
# 1             1  2022          3      Capital Federal        1.545.534
# 2             2  2022          3            Catamarca           70.292
# 3             3  2022          3                Chaco          144.141
# 4             4  2022          3               Chubut          164.874
# ..          ...   ...        ...                  ...              ...
# 835         835  2014          1           Santa Cruz           26.304
# 836         836  2014          1             Santa Fe          506.000
# 837         837  2014          1  Santiago Del Estero           37.124
# 838         838  2014          1     Tierra Del Fuego           27.272
# 839         839  2014          1              Tucumán          129.944
#
#     Dial up      Total
# 0     6.199  4.721.668
# 1     2.145  1.547.679
# 2         1     70.293
# ...

# %%
df4 = pd.read_csv('data_set/internet_fijo_hogar.csv',sep=',')

# %%
df4
# Out:
#      Unnamed: 0   Año  Trimestre            Provincia  \
# 0             0  2022          3         Buenos Aires
# 1             1  2022          3      Capital Federal
# 2             2  2022          3            Catamarca
# 3             3  2022          3                Chaco
# 4             4  2022          3               Chubut
# ..          ...   ...        ...                  ...
# 835         835  2014          1           Santa Cruz
# 836         836  2014          1             Santa Fe
# 837         837  2014          1  Santiago Del Estero
# 838         838  2014          1     Tierra Del Fuego
# 839         839  2014          1              Tucumán
#
#     Accesos por cada 100 hogares
# 0                          78,11
# 1                         122,28
# 2                          65,33
# 3                          43,86
# 4                          84,38
# ..                           ...
# 835                        28,94
# 836                        47,85
# ...

# %%
df5 = pd.read_csv('data_set/internet_fijo_poblacion.csv')

# %%
df5
# Out:
#      Unnamed: 0   Año  Trimestre            Provincia  \
# 0             0  2022          3         Buenos Aires
# 1             1  2022          3      Capital Federal
# 2             2  2022          3            Catamarca
# 3             3  2022          3                Chaco
# 4             4  2022          3               Chubut
# ..          ...   ...        ...                  ...
# 835         835  2014          1           Santa Cruz
# 836         836  2014          1             Santa Fe
# 837         837  2014          1  Santiago Del Estero
# 838         838  2014          1     Tierra Del Fuego
# 839         839  2014          1              Tucumán
#
#      Accesos por cada 100 hab
# 0                          26
# 1                          50
# 2                          17
# 3                          12
# 4                          26
# ..                        ...
# 835                         9
# 836                        15
# 837                         4
# ...

# %%
df6 = pd.read_csv('data_set/internet_fijo_poblacion_hogar.csv', sep =',')

# %%
df6
# Out:
#     Unnamed: 0   Año  Trimestre Accesos por cada 100 hogares  \
# 0            0  2022          3                        76,64
# 1            1  2022          2                        75,97
# 2            2  2022          1                        73,88
# 3            3  2021          4                        73,18
# 4            4  2021          3                        70,58
# 5            5  2021          2                        69,24
# 6            6  2021          1                        67,95
# 7            7  2020          4                        67,62
# 8            8  2020          3                        66,31
# 9            9  2020          2                        64,21
# 10          10  2020          1                        62,86
# 11          11  2019          4                        62,92
# 12          12  2019          3                        65,79
# 13          13  2019          2                        64,53
# ...

# %%
df6
# Out:
#     Unnamed: 0   Año  Trimestre Accesos por cada 100 hogares  \
# 0            0  2022          3                        76,64
# 1            1  2022          2                        75,97
# 2            2  2022          1                        73,88
# 3            3  2021          4                        73,18
# 4            4  2021          3                        70,58
# 5            5  2021          2                        69,24
# 6            6  2021          1                        67,95
# 7            7  2020          4                        67,62
# 8            8  2020          3                        66,31
# 9            9  2020          2                        64,21
# 10          10  2020          1                        62,86
# 11          11  2019          4                        62,92
# 12          12  2019          3                        65,79
# 13          13  2019          2                        64,53
# ...

# %%
df_merged = pd.merge(df_merged, df3, on=['Año', 'Trimestre'], how='outer')
df_merged = pd.merge(df_merged, df4, on=['Año', 'Trimestre'], how='outer')
df_merged = pd.merge(df_merged, df5, on=['Año', 'Trimestre'], how='outer')
df_merged = pd.merge(df_merged, df6, on=['Año', 'Trimestre'], how='outer')

# %% [markdown]
# <!-- df_merged = pd.merge(df_merged, df4, on=['Año', 'Trimestre'], how='outer')
# df_merged = pd.merge(df_merged, df5, on=['Año', 'Trimestre'], how='outer')
# df_merged = pd.merge(df_merged, df6, on=['Año', 'Trimestre'], how='outer') -->

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483844 entries, 0 to 483843
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Año                             483844 non-null  int64
#  1   Trimestre                       483844 non-null  int64
#  2   IPC US                          248836 non-null  float64
#  3   IPC AR                          248836 non-null  float64
#  4   USDARS oficial                  248836 non-null  object
#  5   USDARS blue                     248836 non-null  object
#  6   PBI millones                    235012 non-null  object
#  7   Ingresos (miles de pesos)       483840 non-null  object
#  8   Periodo_x                       483840 non-null  object
#  9   Banda ancha fija_x              483840 non-null  object
#  10  Dial up_x                       483840 non-null  float64
#  11  Total_x                         483840 non-null  object
# ...

# %%
df_merged
# Out:
#     Unnamed: 0_x   Año  Trimestre    IPC US  IPC AR USDARS oficial  \
# 0            0.0  2013          1  232773.0   298.0           5,00
# 1            1.0  2013          2  233504.0   309.0           5,00
# 2            2.0  2013          3  234149.0   331.0           6,00
# 3            3.0  2013          4  233049.0   351.0           6,00
# 4            4.0  2014          1  236293.0   402.0           8,00
# 5            5.0  2014          2  238343.0   433.0           8,00
# 6            6.0  2014          3  238031.0   461.0           8,00
# 7            7.0  2014          4  234812.0   491.0           9,00
# 8            8.0  2015          1  236119.0   518.0           9,00
# 9            9.0  2015          2  238638.0   549.0           9,00
# 10          10.0  2015          3  237945.0   584.0           9,00
# 11          11.0  2015          4  236525.0   621.0          10,00
# 12          12.0  2016          1  238132.0   697.0          14,00
# ...

# %%
df7 = pd.read_csv('data_set/internet_fijo_tecno_loc.csv', sep =',')

# %%
df7
# Out:
#       Unnamed: 0     Provincia      Partido  \
# 0              0  BUENOS AIRES   25 de Mayo
# 1              1  BUENOS AIRES   25 de Mayo
# 2              2  BUENOS AIRES   25 de Mayo
# 3              3  BUENOS AIRES   25 de Mayo
# 4              4  BUENOS AIRES   25 de Mayo
# ...          ...           ...          ...
# 3137        3137       TUCUMAN   Tafí Viejo
# 3138        3138       TUCUMAN      Trancas
# 3139        3139       TUCUMAN      Trancas
# 3140        3140       TUCUMAN  Yerba Buena
# 3141        3141       TUCUMAN  Yerba Buena
#
#                                Localidad Link Indec   ADSL CABLEMODEM DIAL UP  \
# 0                             25 de Mayo    6854100    873      4.704     - 0
# 1                              Del Valle    6854020    181        - 0     - 0
# 2                      Gobernador Ugarte    6854040    - 0        - 0     - 0
# 3                 Norberto de la Riestra    6854060    - 0        782     - 0
# ...

# %%
df8 = pd.read_csv('data_set/internet_fijo_veloc_bajada_loc.csv', sep =',')

# %%
df8.head(2)
# Out:
#    Unnamed: 0     Provincia     Partido        Localidad Link Indec Otros  \
# 0           0  BUENOS AIRES  25 de Mayo       25 de Mayo    6854100   NaN
# 1           1  BUENOS AIRES  25 de Mayo  Agustín Mosconi    6854010   NaN
#
#    0,256 mbps  0,375 mbps 0,5 mbps  0,512 mbps  ...  75 mbps 78 mbps 80 mbps  \
# 0         NaN         NaN        2         NaN  ...      NaN     NaN     9.0
# 1         NaN         NaN      NaN         NaN  ...      NaN     NaN     NaN
#
#    82 mbps 83 mbps 85 mbps  90 mbps  92 mbps 95 mbps  100 mbps
# 0      NaN     NaN     NaN      NaN      NaN     NaN       NaN
# 1      NaN     NaN     NaN      NaN      NaN     NaN       NaN
#
# [2 rows x 84 columns]

# %%
df9 = pd.read_csv('data_set/internet_fijo_veloc_bajada_prov.csv', sep =',')

# %%
df9.head(2)
# Out:
#    Unnamed: 0     Año  Trimestre        Provincia    Otros 0,256 Mbps  \
# 0           0  2022.0        3.0     Buenos Aires   65,821         19
# 1           1  2022.0        3.0  Capital Federal  105,477         31
#
#   0,375 Mbps 0,625 Mbps 0,5 Mbps 0,512 Mbps  ... 70 Mbps 71 Mbps 75 Mbps  \
# 0        - 0        - 0   29,774        192  ...   3,163     - 0  98,387
# 1        - 0        - 0      451         35  ...       3     - 0  30,482
#
#   77 Mbps 78 Mbps 80 Mbps 81 Mbps 83 Mbps 82 Mbps 86 Mbps
# 0     - 0       2     223     - 0       1     - 0     - 0
# 1     - 0     - 0       8     - 0     - 0     - 0     - 0
#
# [2 rows x 98 columns]

# %%
df10 = pd.read_csv('data_set/internet_rango_vel.csv', sep = ',')

# %%
df10.head(2)
# Out:
#    Unnamed: 0   Año  Trimestre  Hasta 512 kbps  Entre 512 Kbps y 1 Mbps  \
# 0           0  2022          3          33.013                   96.727
# 1           1  2022          2          33.667                   99.498
#
#   Entre 1 Mbps y 6 Mbps Entre 6 Mbps y 10 Mbps Entre 10 Mbps y 20 Mbps  \
# 0             1.161.370              1.151.906                 823.505
# 1             1.193.090              1.197.030                 856.562
#
#   Entre 20 Mbps y 30 Mbps Más de 30 Mbps    OTROS       Total  Unnamed: 11
# 0                 479.822      6.995.750  349.035  11.091.128          NaN
# 1                 485.321      6.741.922  351.594  10.958.684          NaN

# %%
df11 = pd.read_csv('data_set/internet_rango_vel_prov.csv', sep=',')

# %%
df11.head(2)
# Out:
#    Unnamed: 0   Año  Trimestre        Provincia  HASTA 512 kbps  \
# 0           0  2022          3     Buenos Aires          29.985
# 1           1  2022          3  Capital Federal         517.000
#
#    + 512 Kbps - 1 Mbps + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  \
# 0               27.709           290.315             297.915
# 1                5.742            34.371              67.829
#
#    + 10 Mbps - 20 Mbps  + 20 Mbps - 30 Mbps  + 30 Mbps    OTROS      Total
# 0              267.044              124.190  3.618.689   65.821  4.721.668
# 1               51.946               28.692  1.253.105  105.477  1.547.679

# %%
df12 = pd.read_csv('data_set/internet_tecno_nacional.csv', sep = ',')

# %%
df12.head(2)
# Out:
#    Unnamed: 0   Año  Trimestre       ADSL Cablemodem Fibra óptica  Wireless  \
# 0           0  2022          3  1.395.277  6.031.970    2.871.541   557.110
# 1           1  2022          2  1.468.333  5.979.214    2.723.285   556.243
#
#      Otros       Total        Periodo
# 0  235.230  11.091.128  Jul-Sept 2022
# 1  231.609  10.958.684   Abr-Jun 2022

# %%
df13 = pd.read_csv('data_set/internet_tecno_prov.csv', sep =',')

# %%
df13.head(2)
# Out:
#    Unnamed: 0   Año Trimestre        Provincia     ADSL Cablemodem  \
# 0           0  2022         3     Buenos Aires  339.648  2.748.325
# 1           1  2022         3  Capital Federal  140.791  1.240.125
#
#   Fibra óptica  Wireless   Otros      Total
# 0    1.436.433   126.846  70.416  4.721.668
# 1      129.218     5.758  31.787  1.547.679

# %%
df14 = pd.read_csv('data_set/loc_tipo_conexion.csv', sep = ',')

# %%
df14.head(2)
# Out:
#    Unnamed: 0.1    Unnamed: 0       Partido      Localidad ADSL Unnamed: 4  \
# 0             0           NaN  Bahía Blanca  Villa Bordeau  NaN        NaN
# 1             1  BUENOS AIRES           NaN   Villa Espora   --         --
#
#   DIALUP FIBRAOPTICA   4G Unnamed: 8 TELEFONIAFIJA Unnamed: 10 SATELITAL
# 0     --          --  NaN        NaN            --         NaN        --
# 1    NaN          --   --         --           NaN          --       NaN

# %%
df15 = pd.read_csv('data_set/tecnologia_loc.csv', sep = ',')

# %%
df15.head(2)
# Out:
#    Unnamed: 0.1    Unnamed: 0       Partido      Localidad  Unnamed: 3  \
# 0             0           NaN  Bahía Blanca  Villa Bordeau         0.0
# 1             1  BUENOS AIRES           NaN            NaN         0.0
#
#   Unnamed: 4 CABLEMODEM DIALUP Unnamed: 7 Unnamed: 8 WIRELESS TELEFONIAFIJA  \
# 0        NaN         --     --         --        NaN       --            --
# 1         --        NaN    NaN         --         --      NaN           NaN
#
#   Unnamed: 11 Unnamed: 12       link            Latitud        Unnamed: 15
# 0         NaN          SI  6056020.0  -38,6472605094596                NaN
# 1          --          --        NaN  -38,7765069529222  -62,1851833537179

# %%
df16 = pd.read_csv('data_set/veloc_media_nacional.csv', sep =',')

# %%
df16.head(2)
# Out:
#    Unnamed: 0   Año  Trimestre Mbps (Media de bajada)    Trimestre.1
# 0           0  2022          3                  62,46  Jul-Sept 2022
# 1           1  2022          2                  58,44   Abr-Jun 2022

# %%
df17 = pd.read_csv('data_set/veloc_media_prov.csv', sep = ',')

# %%
df17.head(2)
# Out:
#    Unnamed: 0   Año  Trimestre        Provincia  Mbps (Media de bajada)  \
# 0           0  2022          3     Buenos Aires                      70
# 1           1  2022          3  Capital Federal                     101
#
#    Unnamed: 4  Unnamed: 5
# 0         NaN         NaN
# 1         NaN         NaN

# %%
# Elminamos las coluimnas unnamed de los dataframe

df = df.drop(columns=['Unnamed: 0'])
df1 = df1.drop(columns=['Unnamed: 0'])
df2 = df2.drop(columns=['Unnamed: 0'])
df3 = df3.drop(columns=['Unnamed: 0'])
df4 = df4.drop(columns=['Unnamed: 0'])
df5 = df5.drop(columns=['Unnamed: 0'])
df6 = df6.drop(columns=['Unnamed: 0'])
df7 = df7.drop(columns=['Unnamed: 0'])
df8 = df8.drop(columns=['Unnamed: 0'])
df9 = df9.drop(columns=['Unnamed: 0'])
df10 = df10.drop(columns=['Unnamed: 0'])
df11 = df11.drop(columns=['Unnamed: 0'])
df12 = df12.drop(columns=['Unnamed: 0'])
df13 = df13.drop(columns=['Unnamed: 0'])
df14 = df14.drop(columns=['Unnamed: 0'])
df15 = df15.drop(columns=['Unnamed: 0'])
df16 = df16.drop(columns=['Unnamed: 0'])
df17 = df17.drop(columns=['Unnamed: 0'])
